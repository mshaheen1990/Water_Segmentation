# %% [markdown]
# # U-Net Early Fusion (Manifest + Locked UUID Split)\nUses clean_manifest.csv and uuid_split_seed42.json via configs/paths_colab.yaml.

# %%
# !pip install -q -r Requirements.txt

# %%
from google.colab import drive\ndrive.mount('/content/drive')\n%cd /content/drive/MyDrive/WaterMaskProject/repo/Water_Segmentation

# %%
# !python src/train_unet_earlyfusion.py --config configs/experiments/unet_earlyfusion.yaml

# %%
# !python src/evaluate.py --config configs/experiments/unet_earlyfusion.yaml
